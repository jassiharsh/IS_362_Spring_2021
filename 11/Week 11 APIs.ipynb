# %% [markdown]
# # Creating a Dataframe from an API

# %%
import pandas as pd
import requests
import json

#api key
api_key = "S8zHEEG45YRfqFuF9SEuVmsvniB9lhtO"
# resource url
url = "https://api.nytimes.com/svc/archive/v1/2012/2.json?&query=smoking&api-key= " + api_key
r = requests.get(url)

# get json
request_data= r.json()
# filter to get required data
data=request_data['response']['docs']

# create a dataframe
df = pd.DataFrame(data)
df.head()
# Out:
#                                             abstract  \
# 0  Listeners to the Brian Lehrer Show weigh in on...
# 1  A week before the city's Panel for Educational...
# 2  Daniel Druckman is conducting the Juilliard Pe...
# 3  The Opera Orchestra of New York performed “Rie...
# 4                          Mike Tanier at Media Day.
#
#                                              web_url  \
# 0  https://www.nytimes.com/schoolbook/2012/01/31/...
# 1  https://www.nytimes.com/schoolbook/2012/01/31/...
# 2  https://www.nytimes.com/2012/02/01/arts/music/...
# 3  https://www.nytimes.com/2012/02/01/arts/music/...
# 4  https://www.nytimes.com/video/multimedia/10000...
#
#                                              snippet  \
# 0  Listeners to the Brian Lehrer Show weigh in on...
# 1  A week before the city's Panel for Educational...
# 2  Daniel Druckman is conducting the Juilliard Pe...
# 3  The Opera Orchestra of New York performed “Rie...
# 4                          Mike Tanier at Media Day.
#
#                                       lead_paragraph              source  \
# 0                                                     The New York Times
# 1                                                     The New York Times
# 2  On Monday evening during the second program in...  The New York Times
# 3  “Rienzi,” Wagner’s third opera, is seldom perf...  The New York Times
# 4                          Mike Tanier at Media Day.  The New York Times
#
#                                           multimedia  \
# 0                                                 []
# 1                                                 []
# 2  [{'rank': 0, 'subtype': 'jumbo', 'caption': No...
# 3  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             headline  \
# 0  {'main': 'Should States Raise the Age of Manda...
# 1  {'main': 'Mayoral Hopefuls Protest School Clos...
# 2  {'main': 'Rhythms, Pummeling or Wondrously Del...
# 3  {'main': 'An Early Wagner, but With All the Tr...
# 4  {'main': 'Super Bowl Media Day: Ross Ventrone'...
#
#                                             keywords  \
# 0                                                 []
# 1                                                 []
# 2  [{'name': 'organizations', 'value': 'Juilliard...
# 3  [{'name': 'organizations', 'value': 'Opera Orc...
# 4  [{'name': 'subject', 'value': 'Football', 'ran...
#
#                    pub_date document_type news_desk       section_name  \
# 0  2012-02-01T00:00:06+0000       article                    Education
# 1  2012-02-01T00:00:06+0000       article                    Education
# 2  2012-02-01T00:03:40+0000       article   Culture               Arts
# 3  2012-02-01T00:07:10+0000       article   Culture               Arts
# 4  2012-02-01T00:10:30+0000    multimedia            Multimedia/Photos
#
#                                               byline type_of_material  \
# 0  {'original': 'By PATRICIA WILLENS', 'person': ...             News
# 1  {'original': 'By BETH FERTIG', 'person': [{'fi...             News
# 2  {'original': 'By Anthony Tommasini', 'person':...           Review
# 3  {'original': 'By Anthony Tommasini', 'person':...           Review
# 4  {'original': 'Justin Sablich', 'person': [{'fi...            Video
#
#                                                  _id  word_count  \
# 0  nyt://article/93a8ae96-e347-52ee-84f5-c5070826...           0
# 1  nyt://article/9866d5d7-fa0c-57bf-9f58-daff6a09...           0
# 2  nyt://article/f8daf712-b19d-5b43-b584-0adf3ca3...         527
# 3  nyt://article/007d7c68-99d4-58d7-87b0-30954c7e...         609
# 4   nyt://video/df1430d2-b361-5ca1-b575-f1d51d432160           0
#
#                                                  uri print_section print_page  \
# 0  nyt://article/93a8ae96-e347-52ee-84f5-c5070826...           NaN        NaN
# 1  nyt://article/9866d5d7-fa0c-57bf-9f58-daff6a09...           NaN        NaN
# 2  nyt://article/f8daf712-b19d-5b43-b584-0adf3ca3...             C          7
# 3  nyt://article/007d7c68-99d4-58d7-87b0-30954c7e...             C          4
# 4   nyt://video/df1430d2-b361-5ca1-b575-f1d51d432160           NaN        NaN
#
#   subsection_name
# 0             NaN
# 1             NaN
# 2           Music
# 3           Music
# 4             NaN
